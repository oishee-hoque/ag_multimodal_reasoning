# %% [markdown]
# # Field-level feature analysis
#
# This notebook is a starter for interactive exploration of extracted field features, classifier performance, and SHAP outputs.

# %%
import pandas as pd
from pathlib import Path

features_csv = Path('data/field_features_utah.csv')
if features_csv.exists():
    df = pd.read_csv(features_csv)
    display(df.head())
    print(df.shape)
