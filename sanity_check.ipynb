# %%
from irrigation.data.bands import get_band_config
from irrigation.data.dataset import IrrigationDataset

ds = IrrigationDataset(
    data_root="/path/to/Colorado",
    tile_ids=[0, 1, 2],
    band_config=get_band_config("rgb_s4"),
)
sample = ds[0]
print(sample["image"].shape, sample["label"].shape)
print("Label classes:", sample["label"].unique())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from irrigation.data.bands import get_band_config
#       2 from irrigation.data.dataset import IrrigationDataset
#       4 ds = IrrigationDataset(
#       5     data_root="/path/to/Colorado",
#       6     tile_ids=[0, 1, 2],
#       7     band_config=get_band_config("rgb_s4"),
#       8 )
#
# ModuleNotFoundError: No module named 'irrigation'
