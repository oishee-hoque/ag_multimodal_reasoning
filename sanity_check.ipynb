# %%
import sys
sys.path.insert(0, "/scratch/gza5dr/IrrigationType_experiments/mutli_reasoning/src")

from irrigation.data.bands import get_band_config
from irrigation.data.dataset import IrrigationDataset

ds = IrrigationDataset(
    data_root="/scratch/gza5dr/IrrigationType_experiments/Colorado/Data/Claude_Code/irrigation_dataset/Utah",
    tile_ids=[0, 1, 2],
    band_config=get_band_config("rgb_s4"),
)
sample = ds[0]
print(sample["image"].shape, sample["label"].shape)
print("Label classes:", sample["label"].unique())
# Out:
# torch.Size([3, 224, 224]) torch.Size([224, 224])
# Label classes: tensor([0, 2])
